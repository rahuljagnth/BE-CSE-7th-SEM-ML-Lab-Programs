# %%
import math 
import csv

def load_csv(filename):
    lines = csv.reader(open(filename, "r")); 
    dataset = list(lines)
    headers = dataset.pop(0)
    return dataset, headers

class Node:
    def __init__(self, attribute): 
        self.attribute = attribute 
        self.children = []
        self.answer = ""     # NULL indicates children exists. # Not Null indicates this is a Leaf Node

def subtables(data, col, delete): 
    dic = {}
    coldata = [ row[col] for row in data]
    attr = list(set(coldata))    # All values of attribute retrived
    
    counts = [0]*len(attr) 
    r = len(data)
    c = len(data[0])
    for x in range(len(attr)): 
        for y in range(r):
            if data[y][col] == attr[x]: 
                counts[x] += 1

    for x in range(len(attr)):
        dic[attr[x]] = [[0 for i in range(c)] for j in range(counts[x])] 
        pos = 0
        for y in range(r):
            if data[y][col] == attr[x]: 
                if delete:
                    del data[y][col] 
                dic[attr[x]][pos] = data[y]
                pos += 1
    return attr, dic 
    
def entropy(S):
    attr = list(set(S))
    if len(attr) == 1:        #if all are +ve/-ve then entropy = 0 
        return 0

    counts = [0,0]           # Only two values possible 'yes' or 'no' 
    for i in range(2):
        counts[i] = sum( [1 for x in S if attr[i] == x] ) / (len(S) * 1.0)

    sums = 0
    for cnt in counts:
        sums += -1 * cnt * math.log(cnt, 2)

    return sums
def compute_gain(data, col):
    attValues, dic = subtables(data, col, delete=False)
    
    
    total_entropy = entropy([row[-1] for row in data])
    for x in range(len(attValues)):
        ratio = len(dic[attValues[x]]) / ( len(data) * 1.0)
        entro = entropy([row[-1] for row in dic[attValues[x]]])
        total_entropy -= ratio*entro

    return total_entropy
    
def build_tree(data, features): 
    lastcol = [row[-1] for row in data]
    if (len(set(lastcol))) == 1:            # If all samples have same labels return that label 
        node=Node("")
        node.answer = lastcol[0] 
        return node

    n = len(data[0])-1
    gains = [0]*n
    for col in range(n):
       
        gains[col] = compute_gain(data, col)
       

    split = gains.index(max(gains))         # Find max gains and returns index 
   
    node = Node(features[split])           # 'node' stores attribute selected 
    
    
    fea = features[:split]+features[split+1:]
    
    
    attr, dic = subtables(data, split, delete=True)     # Data will be spilt in subtables 
    
    for x in range(len(attr)):
        child = build_tree(dic[attr[x]], fea)
        
        node.children.append((attr[x], child))
        
    return node

def print_tree(node, level): 
    if node.answer != "":
        print(" "*level, node.answer)          # Displays leaf node yes/no 
        return

    print(" "*level, node.attribute)           # Displays attribute Name 
    for value, n in node.children:        
        print_tree(n, level + 2)

def classify(node,x_test,features): 
    if node.answer != "":
        print(node.answer) 
        return

    pos = features.index(node.attribute)
   
    for value, n in node.children:
             
        if x_test[pos]==value:
            print('x_test[pos] -----',x_test[pos])
            print('value -----',value)
            classify(n,x_test,features)

#''' Main program '''

dataset, features = load_csv("data3_test.csv")        # Read Tennis data
print('features -',features)
node = build_tree(dataset, features)                  # Build decision tree
print("The decision tree for dataset using ID3 algorithm is ") 
print_tree(node, 0)

testdata, features = load_csv("data3_test.csv") 

for xtest in testdata:
    print("Test instance : ",xtest) 
    print("Predicted label : ", end="") 
    classify(node,xtest,features)
# Out:
# features - ['Outlook', 'Temperature', 'Humidity', 'Wind', 'Target']
# The decision tree for dataset using ID3 algorithm is
#  Outlook
#    Humidity
#      yes
#      no
#    yes
#    Wind
#      yes
#      Temperature
#        no
#        no
# Test instance :  ['sunny', 'hot', 'high', 'weak', 'no ']
# Predicted label : x_test[pos] ----- sunny
# value ----- sunny
# x_test[pos] ----- high
# value ----- high
# no
# Test instance :  ['sunny', 'hot', 'high', 'strong', 'no ']
# Predicted label : x_test[pos] ----- sunny
# value ----- sunny
# x_test[pos] ----- high
# value ----- high
# no
# Test instance :  ['overcast', 'hot', 'high', 'weak', 'yes ']
# Predicted label : x_test[pos] ----- overcast
# value ----- overcast
# yes
# Test instance :  ['rain', 'mild', 'high', 'weak', 'yes ']
# Predicted label : x_test[pos] ----- rain
# value ----- rain
# x_test[pos] ----- weak
# value ----- weak
# yes
# Test instance :  ['rain', 'cool', 'normal', 'weak', 'yes ']
# Predicted label : x_test[pos] ----- rain
# value ----- rain
# x_test[pos] ----- weak
# value ----- weak
# yes
# Test instance :  ['rain', 'cool', 'normal', 'strong', 'no ']
# Predicted label : x_test[pos] ----- rain
# value ----- rain
# x_test[pos] ----- strong
# value ----- strong
# x_test[pos] ----- cool
# value ----- cool
# no
# Test instance :  ['overcast', 'cool', 'normal', 'strong', 'yes ']
# Predicted label : x_test[pos] ----- overcast
# value ----- overcast
# yes
# Test instance :  ['sunny', 'mild', 'high', 'weak', 'no ']
# Predicted label : x_test[pos] ----- sunny
# value ----- sunny
# x_test[pos] ----- high
# value ----- high
# no
# Test instance :  ['sunny', 'cool', 'normal', 'weak', 'yes ']
# Predicted label : x_test[pos] ----- sunny
# value ----- sunny
# x_test[pos] ----- normal
# value ----- normal
# yes
# Test instance :  ['rain', 'mild', 'normal', 'weak', 'yes ']
# Predicted label : x_test[pos] ----- rain
# value ----- rain
# x_test[pos] ----- weak
# value ----- weak
# yes
# Test instance :  ['sunny', 'mild', 'normal', 'strong', 'yes ']
# Predicted label : x_test[pos] ----- sunny
# value ----- sunny
# x_test[pos] ----- normal
# value ----- normal
# yes
# Test instance :  ['overcast', 'mild', 'high', 'strong', 'yes ']
# Predicted label : x_test[pos] ----- overcast
# value ----- overcast
# yes
# Test instance :  ['overcast', 'hot', 'normal', 'weak', 'yes ']
# Predicted label : x_test[pos] ----- overcast
# value ----- overcast
# yes
# Test instance :  ['rain', 'mild', 'high', 'strong', 'no']
# Predicted label : x_test[pos] ----- rain
# value ----- rain
# x_test[pos] ----- strong
# value ----- strong
# x_test[pos] ----- mild
# value ----- mild
# no
